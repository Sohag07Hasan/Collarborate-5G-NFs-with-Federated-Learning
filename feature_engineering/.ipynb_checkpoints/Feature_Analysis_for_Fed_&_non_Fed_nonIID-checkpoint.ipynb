# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
import os
from tqdm import tqdm
import seaborn as sns

import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
#import ace_tools as tools
# OR, if using Jupyter Notebook
from IPython.display import display
#display(clustered_features_df)

# %%
def read_all_csv_files(directory_path, features, limit=10000):
    # Initialize an empty list to store dataframes from CSV files
    dataframes = []

    # Get a list of all files in the directory
    file_list = os.listdir(directory_path)

    # Loop through each file and check if it's a CSV file
    for file_name in file_list:
        if file_name.endswith('.csv'):
            # Get the full file path
            file_path = os.path.join(directory_path, file_name)
            # Read the CSV file into a pandas DataFrame
            df = pd.read_csv(file_path)
            # Remove leading and trailing spaces from column names
            df.columns = df.columns.str.strip()
            # Append the DataFrame to the list
            dataframes.append(df[features])

    # Merge all DataFrames into a single DataFrame
    merged_df = pd.concat(dataframes, ignore_index=True)
    print("Initial Row: {}".format(merged_df.shape[0]))
    
    #applying limit if row_count > limit
    if len(merged_df) > limit:
        print("As Row Exceeds {0}, we are taking upto {1} rows".format(limit, limit))
        merged_df = merged_df.sample(limit, random_state=42)
    
    return merged_df

# %%
#Data Sources
PATH = './dataset_nonIID'
clients = {
    'client_1': f"{PATH}/client_1/client_1_original_dataset.csv",
    'client_2': f"{PATH}/client_2/client_2_original_dataset.csv",
    'client_3': f"{PATH}/client_3/client_3_original_dataset.csv",
    'client_4': f"{PATH}/client_4/client_4_original_dataset.csv"
}

# %%
#Tick Names and Numbers
tick_list = list(clients.keys())
tick_numbers = list(range(1, len(tick_list)+1))
print("Tick Lists: {}".format(tick_list))
print("Tick Numbers: {}".format(tick_numbers))
# Out:
# Tick Lists: ['client_1', 'client_2', 'client_3', 'client_4']
# Tick Numbers: [1, 2, 3, 4]

# %%
for key, element in tqdm(clients.items(), total=len(clients)):
    dataframe = pd.read_csv(element)
    locals()[key] = dataframe
    print(f"---------------------{key}----------------------------------")
    print(dataframe.groupby(['Label']).size().reset_index(name="Count"))
    print("------------------------------------------------------------------")
# Out:
#  25%|██████████████████████▊                                                                    | 1/4 [00:02<00:08,  2.89s/it]
# ---------------------client_1----------------------------------
#    Label   Count
# 0      0  202821
# 1      1  217179
# ------------------------------------------------------------------
#  50%|█████████████████████████████████████████████▌                                             | 2/4 [00:05<00:05,  2.87s/it]
# ---------------------client_2----------------------------------
#    Label   Count
# 0      0  185943
# 1      1  234057
# ------------------------------------------------------------------
#  75%|████████████████████████████████████████████████████████████████████▎                      | 3/4 [00:08<00:02,  2.86s/it]
# ---------------------client_3----------------------------------
#    Label   Count
# 0      0  210000
# 1      1  210000
# ------------------------------------------------------------------
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:11<00:00,  2.85s/it]
# ---------------------client_4----------------------------------
#    Label   Count
# 0      0  210000
# 1      1  210000
# ------------------------------------------------------------------

# %%
# def draw_box_plot(data, tick_numbers, tick_list, title, x_label="", y_label="", show_outliers=False):
#     fig, ax = plt.subplots(figsize=(6,4))
#     plt.suptitle(title)
#     ax = fig.add_axes([0, 0, 1, 1])
#     bp = ax.boxplot(data, showfliers=show_outliers, patch_artist=True)
#     plt.xticks(tick_numbers, tick_list)
#     plt.xticks(rotation=90)
#     ax.set_ylabel(y_label)
#     plt.show()

# %%
# ##Flow Duration
# data = []
# for key, element in clients.items():
#     data.append(locals()[key]['Flow Duration']/1000000)

# draw_box_plot(data, tick_numbers, tick_list, 'Flow Duration', '', 'Seconds', True)

# #draw_box_plot(data, tick_numbers, tick_list, 'Flow Duration', '', 'Seconds', False)

# %%
# ##Total  Packets
# data = []
# for key, element in clients.items():
#     data.append(locals()[key]['Total Bwd packets'] + locals()[key]['Total Fwd Packet'])

# draw_box_plot(data, tick_numbers, tick_list, 'Total Packet Count', '', 'Count', True)
# #draw_box_plot(data, tick_numbers, tick_list, 'Total Packet Count', '', 'Count', False)

# %%
# ##Total Lenght of Packets Packets
# data = []
# for key, element in clients.items():
#     data.append(locals()[key]['Packet Length Mean'])

# draw_box_plot(data, tick_numbers, tick_list, 'Packet Length Mean', '', 'Byte', True)
# #draw_box_plot(data, tick_numbers, tick_list, 'Packet Length Mean', '', 'Byte', False)

# %%
# ##TFlow Bytes/s (kbps)
# data = []
# for key, element in clients.items():
#     data.append(locals()[key]['Flow Bytes/s']*8/1000000) #making it kbps from Byte/s

# draw_box_plot(data, tick_numbers, tick_list, 'Flow Bytes/s', '', 'Mbps', True)
# #draw_box_plot(data, tick_numbers, tick_list, 'Flow Bytes/s', '', 'Kbps', False)

# %%
# ##TFlow Bytes/s (kbps)
# data = []
# for key, element in clients.items():
#     data.append(locals()[key]['Flow Packets/s']*8/1000) #making it kbps from Byte/s

# draw_box_plot(data, tick_numbers, tick_list, 'Flow Packets/s', '', 'Packets/s', True)
# draw_box_plot(data, tick_numbers, tick_list, 'Flow Packets/s', '', 'Packets/s', False)

# %% [markdown]
# ## Manual Feature Analysis

# %%
test_features = ['Flow Duration' ,'Total Fwd Packet' ,'Total Bwd packets' ,'Total Length of Fwd Packet' ,'Total Length of Bwd Packet' ,'Fwd Packet Length Max' ,'Fwd Packet Length Min' ,'Fwd Packet Length Std' ,'Bwd Packet Length Max' ,'Bwd Packet Length Min' ,'Bwd Packet Length Std' ,'Flow IAT Mean' ,'Flow IAT Std' ,'Flow IAT Max' ,'Flow IAT Min' ,'Fwd IAT Total' ,'Fwd IAT Std' ,'Fwd IAT Max' ,'Fwd IAT Min' ,'Bwd IAT Total' ,'Bwd IAT Std' ,'Bwd IAT Max' ,'Bwd IAT Min' ,'Fwd Header Length' ,'Bwd Header Length' ,'Packet Length Min' ,'Packet Length Max' ,'Packet Length Std' ,'Packet Length Variance' ,'FWD Init Win Bytes' ,'Bwd Init Win Bytes' ,'Fwd Act Data Pkts' ,'Fwd Seg Size Min' ,'Active Mean' ,'Active Std' ,'Active Max' ,'Active Min' ,'Idle Mean' ,'Idle Std' ,'Idle Max' ,'Idle Min', 'Label']

# %%
# def measure_correlation(df, co_efficent=0.2, precision=5, noise_level=1e-6):
#     # Calculate correlation matrix for numeric features
#     correlation_matrix = df.corr()    
#     # Find features with low correlation with other features
#     # We use 0.2 as the threshold for weak correlation (you can adjust it as needed)

#     # We use 0.2 as the threshold for weak correlation (you can adjust it as needed)
#     independent_features = correlation_matrix[correlation_matrix.abs() < co_efficent].count().sort_values(ascending=False)
    
#     # Create a DataFrame with the feature names and their respective counts of low-correlation (independent) scores
#     independent_features_df = pd.DataFrame({
#         'Feature': independent_features.index,
#         'Score': independent_features.values
#     })
     

#     # Draw a heatmap for the correlation matrix
#     plt.figure(figsize=(12, 10))
#     sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", cbar=True)
    
#     # Display the heatmap
#     plt.title('Correlation Matrix of Features')
#     plt.show()
#     return independent_features_df

# %%
# def measure_correlation(df, co_efficent=0.2, precision=5, noise_level=1e-6):
#     """
#     Measures feature independence using correlation and ensures unique scores.
    
#     Args:
#         df (pd.DataFrame): Input DataFrame.
#         co_efficent (float): Threshold for weak correlation.
#         precision (int): Decimal places for correlation matrix.
#         noise_level (float): Tiny noise added to break ties.

#     Returns:
#         pd.DataFrame: Independent features with unique scores.
#     """

#     # Calculate correlation matrix with high precision
#     correlation_matrix = df.corr().round(precision)  # Ensure precise computation
    
#     # Find independent features based on the threshold
#     independent_features = correlation_matrix[correlation_matrix.abs() < co_efficent].count().sort_values(ascending=False)

#     # Store as DataFrame
#     independent_features_df = pd.DataFrame({
#         'Feature': independent_features.index,
#         'Score': independent_features.values
#     })

#     # Apply tie-breaking by adding tiny noise
#     independent_features_df["Score"] += np.random.uniform(-noise_level, noise_level, size=len(independent_features_df))

#     # Re-sort to reflect the updated uniqueness
#     independent_features_df = independent_features_df.sort_values(by="Score", ascending=False).reset_index(drop=True)

#     # Draw a heatmap for better visualization
#     plt.figure(figsize=(12, 10))
#     sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", cbar=True)
#     plt.title('Correlation Matrix of Features')
#     plt.show()

#     return independent_features_df

# %%
# # Assuming 'clients' is a dictionary of client dataframes
# all_independent_features = pd.DataFrame()

# for key, element in clients.items():
#     print(key)
#     independent_features_df =  measure_correlation(locals()[key][test_features], co_efficent = 0.01)
#      # Rename 'Score' column to 'Score_X' where X is the current iteration number
#     independent_features_df.rename(columns={'Score': f'Score_{key}'}, inplace=True)

#     # Merge the results to keep the 'Feature' column as the common key
#     if all_independent_features.empty:
#         all_independent_features = independent_features_df
#     else:
#         all_independent_features = pd.merge(all_independent_features, independent_features_df, on='Feature', how='outer')

    
# # Display the final combined DataFrame
# #print(all_independent_features)

# %%
#all_independent_features.to_csv("Feature_Correlation_Scores.csv", index=False)

# %%
def cluster_correlated_features(df, threshold=0.95):
    # Compute the correlation matrix
    correlation_matrix = df.corr().abs()  # Get absolute correlation values

    # Convert correlation matrix to distance matrix (1 - correlation)
    distance_matrix = 1 - correlation_matrix

    # Perform hierarchical clustering
    linkage_matrix = sch.linkage(distance_matrix, method='ward')
    
    # Create clusters based on the threshold
    cluster_model = AgglomerativeClustering(n_clusters=None, distance_threshold=1-threshold, linkage='ward')
    cluster_labels = cluster_model.fit_predict(distance_matrix)

    # Create a DataFrame showing feature groups
    clustered_features = pd.DataFrame({
        "Feature": df.columns,
        "Cluster": cluster_labels
    })

    # Sort by cluster
    clustered_features = clustered_features.sort_values(by="Cluster")
    
    # Plot dendrogram
    plt.figure(figsize=(12, 6))
    sch.dendrogram(linkage_matrix, labels=df.columns, leaf_rotation=90)
    plt.title('Hierarchical Clustering Dendrogram of Features')
    plt.xlabel('Features')
    plt.ylabel('Distance')
    plt.show()
    
    return clustered_features

# %%
for key, element in clients.items():
    print(key)
    df = locals()[key][test_features]
    df = df.drop(columns=["Label"])
    
    clustered_features_df = cluster_correlated_features(df, threshold=0.95)
    display(clustered_features_df)
    #tools.display_dataframe_to_user(name="Clustered Highly Correlated Features", dataframe=clustered_features_df)
# Out:
# client_1
# /tmp/ipykernel_3100322/1643645634.py:9: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                        Feature  Cluster
# 39                    Idle Max        0
# 17                 Fwd IAT Max        0
# 13                Flow IAT Max        0
# 1             Total Fwd Packet        1
# 24           Bwd Header Length        1
# 23           Fwd Header Length        1
# 40                    Idle Min        2
# 2            Total Bwd packets        3
# 4   Total Length of Bwd Packet        3
# 15               Fwd IAT Total        4
# 0                Flow Duration        4
# 32            Fwd Seg Size Min        5
# 38                    Idle Std        6
# 14                Flow IAT Min        7
# 18                 Fwd IAT Min        7
# 34                  Active Std        8
# 36                  Active Min        9
# 25           Packet Length Min       10
# 6        Fwd Packet Length Min       10
# 29          FWD Init Win Bytes       11
# 20                 Bwd IAT Std       12
# 33                 Active Mean       13
# 30          Bwd Init Win Bytes       14
# 31           Fwd Act Data Pkts       15
# 21                 Bwd IAT Max       16
# 11               Flow IAT Mean       17
# 28      Packet Length Variance       18
# 5        Fwd Packet Length Max       19
# 35                  Active Max       20
# 16                 Fwd IAT Std       21
# 37                   Idle Mean       22
# 7        Fwd Packet Length Std       23
# 10       Bwd Packet Length Std       24
# 9        Bwd Packet Length Min       25
# 19               Bwd IAT Total       26
# 22                 Bwd IAT Min       27
# 27           Packet Length Std       28
# 3   Total Length of Fwd Packet       29
# 12                Flow IAT Std       30
# 26           Packet Length Max       31
# 8        Bwd Packet Length Max       32
# client_2
# /tmp/ipykernel_3100322/1643645634.py:9: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                        Feature  Cluster
# 1             Total Fwd Packet        0
# 24           Bwd Header Length        0
# 23           Fwd Header Length        0
# 2            Total Bwd packets        1
# 4   Total Length of Bwd Packet        1
# 0                Flow Duration        2
# 15               Fwd IAT Total        2
# 39                    Idle Max        3
# 17                 Fwd IAT Max        3
# 13                Flow IAT Max        3
# 32            Fwd Seg Size Min        4
# 40                    Idle Min        5
# 38                    Idle Std        6
# 36                  Active Min        7
# 31           Fwd Act Data Pkts        8
# 28      Packet Length Variance        9
# 25           Packet Length Min       10
# 37                   Idle Mean       11
# 35                  Active Max       12
# 10       Bwd Packet Length Std       13
# 29          FWD Init Win Bytes       14
# 33                 Active Mean       15
# 30          Bwd Init Win Bytes       16
# 22                 Bwd IAT Min       17
# 18                 Fwd IAT Min       18
# 16                 Fwd IAT Std       19
# 12                Flow IAT Std       20
# 21                 Bwd IAT Max       21
# 14                Flow IAT Min       22
# 34                  Active Std       23
# 27           Packet Length Std       24
# 5        Fwd Packet Length Max       25
# 11               Flow IAT Mean       26
# 6        Fwd Packet Length Min       27
# 9        Bwd Packet Length Min       28
# 7        Fwd Packet Length Std       29
# 19               Bwd IAT Total       30
# 3   Total Length of Fwd Packet       31
# 20                 Bwd IAT Std       32
# 26           Packet Length Max       33
# 8        Bwd Packet Length Max       34
# client_3
# /tmp/ipykernel_3100322/1643645634.py:9: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                        Feature  Cluster
# 0                Flow Duration        0
# 15               Fwd IAT Total        0
# 6        Fwd Packet Length Min        1
# 25           Packet Length Min        1
# 37                   Idle Mean        2
# 38                    Idle Std        3
# 39                    Idle Max        4
# 13                Flow IAT Max        4
# 34                  Active Std        5
# 35                  Active Max        6
# 30          Bwd Init Win Bytes        7
# 28      Packet Length Variance        8
# 40                    Idle Min        9
# 36                  Active Min       10
# 32            Fwd Seg Size Min       11
# 19               Bwd IAT Total       12
# 20                 Bwd IAT Std       13
# 33                 Active Mean       14
# 29          FWD Init Win Bytes       15
# 24           Bwd Header Length       16
# 23           Fwd Header Length       17
# 16                 Fwd IAT Std       18
# 22                 Bwd IAT Min       19
# 21                 Bwd IAT Max       20
# 9        Bwd Packet Length Min       21
# 31           Fwd Act Data Pkts       22
# 27           Packet Length Std       23
# 26           Packet Length Max       24
# 5        Fwd Packet Length Max       25
# 4   Total Length of Bwd Packet       26
# 7        Fwd Packet Length Std       27
# 11               Flow IAT Mean       28
# 18                 Fwd IAT Min       29
# 12                Flow IAT Std       30
# 10       Bwd Packet Length Std       31
# 3   Total Length of Fwd Packet       32
# 17                 Fwd IAT Max       33
# 2            Total Bwd packets       34
# 14                Flow IAT Min       35
# 1             Total Fwd Packet       36
# 8        Bwd Packet Length Max       37
# client_4
# /tmp/ipykernel_3100322/1643645634.py:9: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                        Feature  Cluster
# 30          Bwd Init Win Bytes        0
# 29          FWD Init Win Bytes        0
# 25           Packet Length Min        1
# 6        Fwd Packet Length Min        1
# 39                    Idle Max        2
# 13                Flow IAT Max        2
# 0                Flow Duration        3
# 15               Fwd IAT Total        3
# 40                    Idle Min        4
# 37                   Idle Mean        5
# 33                 Active Mean        6
# 38                    Idle Std        7
# 26           Packet Length Max        8
# 36                  Active Min        9
# 35                  Active Max       10
# 34                  Active Std       11
# 20                 Bwd IAT Std       12
# 22                 Bwd IAT Min       13
# 27           Packet Length Std       14
# 31           Fwd Act Data Pkts       15
# 32            Fwd Seg Size Min       16
# 17                 Fwd IAT Max       17
# 16                 Fwd IAT Std       18
# 23           Fwd Header Length       19
# 28      Packet Length Variance       20
# 5        Fwd Packet Length Max       21
# 18                 Fwd IAT Min       22
# 19               Bwd IAT Total       23
# 24           Bwd Header Length       24
# 7        Fwd Packet Length Std       25
# 12                Flow IAT Std       26
# 4   Total Length of Bwd Packet       27
# 10       Bwd Packet Length Std       28
# 11               Flow IAT Mean       29
# 21                 Bwd IAT Max       30
# 3   Total Length of Fwd Packet       31
# 2            Total Bwd packets       32
# 1             Total Fwd Packet       33
# 8        Bwd Packet Length Max       34
# 9        Bwd Packet Length Min       35
# 14                Flow IAT Min       36

# %% [markdown]
# ## Make Cluster and then Calculate corelation with Label

# %%
import pandas as pd
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

def get_feature_clusters_and_correlation(df, label_column, cluster_threshold=0.95):
    """
    Performs feature clustering based on correlation and calculates feature-to-label correlation.
    
    :param df: Pandas DataFrame containing features and target label.
    :param label_column: The name of the target variable (binary classification).
    :param cluster_threshold: Threshold for clustering highly correlated features.
    
    :return: DataFrame with Feature Name, Cluster ID, and Correlation with Label.
    """
    # 1️⃣ Compute feature-to-feature correlation matrix
    feature_columns = [col for col in df.columns if col != label_column]
    correlation_matrix = df[feature_columns].corr().abs()  # Absolute correlation
    
    # 2️⃣ Convert correlation matrix to distance matrix (1 - correlation)
    distance_matrix = 1 - correlation_matrix
    
    # 3️⃣ Perform hierarchical clustering (ward linkage minimizes variance)
    linkage_matrix = sch.linkage(distance_matrix, method='ward')
    
    # 4️⃣ Agglomerative clustering to form clusters
    cluster_model = AgglomerativeClustering(n_clusters=None, distance_threshold=1 - cluster_threshold, linkage='ward')
    cluster_labels = cluster_model.fit_predict(distance_matrix)
    
    # 5️⃣ Create DataFrame for feature clusters
    clustered_features = pd.DataFrame({
        "Feature": feature_columns,
        "Cluster": cluster_labels
    })
    
    # 6️⃣ Compute absolute correlation with the label (binary classification)
    feature_label_correlation = df[feature_columns].corrwith(df[label_column]).abs()
    
    # 7️⃣ Merge cluster information with feature-label correlation
    clustered_features["Label_Correlation"] = clustered_features["Feature"].map(feature_label_correlation)
    
    return clustered_features.sort_values(by="Cluster")

# %% [markdown]
# ## Get the Best Features

# %%
def select_best_features_per_cluster(clustered_df):
    """
    Selects the best feature from each cluster based on the highest correlation with the label.
    Sorts the selected features by correlation and assigns a ranking.

    :param clustered_df: DataFrame containing Feature, Cluster, and Label_Correlation columns.
    :param output_file: Name of the CSV file to store the results.

    :return: Ranked DataFrame with the best feature per cluster.
    """
    # 1️⃣ Select the feature with the highest correlation per cluster
    best_features = clustered_df.loc[clustered_df.groupby("Cluster")["Label_Correlation"].idxmax()]
    
    # 2️⃣ Sort by correlation value in descending order
    best_features = best_features.sort_values(by="Label_Correlation", ascending=False).reset_index(drop=True)
    
    # 3️⃣ Add a rank column (1 = highest correlation)
    best_features.insert(0, "Rank", range(1, len(best_features) + 1))
    return best_features

# %%
for key, element in clients.items():
    print(key)
    df = locals()[key][test_features]
    clustered_result = get_feature_clusters_and_correlation(df, label_column="Label", cluster_threshold=0.9)   
    final_features = select_best_features_per_cluster(clustered_result)
    clustered_result.rename(columns={'Feature': 'original'}, inplace=True)
    clustered_result.to_csv(f'./Generated_Feature_FL_non_FL/clusterwise_features_{key}.csv', index=False)

    final_features.rename(columns={'Feature': 'original'}, inplace=True)
    final_features.to_csv(f'./Generated_Feature_FL_non_FL/final_features_{key}.csv', index=False)
    display(clustered_result)
    display(final_features)
# Out:
# client_1
# /tmp/ipykernel_3100322/2158537172.py:23: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                       original  Cluster  Label_Correlation
# 16                 Fwd IAT Std        0           0.044046
# 12                Flow IAT Std        0           0.035472
# 1             Total Fwd Packet        1           0.012771
# 2            Total Bwd packets        1           0.008724
# 4   Total Length of Bwd Packet        1           0.007895
# 23           Fwd Header Length        1           0.011061
# 24           Bwd Header Length        1           0.007734
# 40                    Idle Min        2           0.378210
# 39                    Idle Max        3           0.322463
# 13                Flow IAT Max        3           0.320275
# 17                 Fwd IAT Max        3           0.321354
# 26           Packet Length Max        4           0.902206
# 8        Bwd Packet Length Max        4           0.933181
# 32            Fwd Seg Size Min        5           0.561561
# 38                    Idle Std        6           0.012113
# 14                Flow IAT Min        7           0.641361
# 18                 Fwd IAT Min        7           0.641349
# 34                  Active Std        8           0.035912
# 36                  Active Min        9           0.264013
# 0                Flow Duration       10           0.163394
# 15               Fwd IAT Total       10           0.163974
# 29          FWD Init Win Bytes       11           0.861908
# 20                 Bwd IAT Std       12           0.188264
# 33                 Active Mean       13           0.265806
# 30          Bwd Init Win Bytes       14           0.808621
# 31           Fwd Act Data Pkts       15           0.067480
# 21                 Bwd IAT Max       16           0.148798
# 11               Flow IAT Mean       17           0.610390
# 28      Packet Length Variance       18           0.842325
# 5        Fwd Packet Length Max       19           0.564064
# 35                  Active Max       20           0.256511
# 6        Fwd Packet Length Min       21           0.974219
# 25           Packet Length Min       21           0.974732
# 37                   Idle Mean       22           0.364115
# 7        Fwd Packet Length Std       23           0.687031
# 10       Bwd Packet Length Std       24           0.900274
# 9        Bwd Packet Length Min       25           0.126821
# 19               Bwd IAT Total       26           0.162067
# 22                 Bwd IAT Min       27           0.008896
# 27           Packet Length Std       28           0.908272
# 3   Total Length of Fwd Packet       29           0.060275
#     Rank                    original  Cluster  Label_Correlation
# 0      1           Packet Length Min       21           0.974732
# 1      2       Bwd Packet Length Max        4           0.933181
# 2      3           Packet Length Std       28           0.908272
# 3      4       Bwd Packet Length Std       24           0.900274
# 4      5          FWD Init Win Bytes       11           0.861908
# 5      6      Packet Length Variance       18           0.842325
# 6      7          Bwd Init Win Bytes       14           0.808621
# 7      8       Fwd Packet Length Std       23           0.687031
# 8      9                Flow IAT Min        7           0.641361
# 9     10               Flow IAT Mean       17           0.610390
# 10    11       Fwd Packet Length Max       19           0.564064
# 11    12            Fwd Seg Size Min        5           0.561561
# 12    13                    Idle Min        2           0.378210
# 13    14                   Idle Mean       22           0.364115
# 14    15                    Idle Max        3           0.322463
# 15    16                 Active Mean       13           0.265806
# 16    17                  Active Min        9           0.264013
# 17    18                  Active Max       20           0.256511
# 18    19                 Bwd IAT Std       12           0.188264
# 19    20               Fwd IAT Total       10           0.163974
# 20    21               Bwd IAT Total       26           0.162067
# 21    22                 Bwd IAT Max       16           0.148798
# 22    23       Bwd Packet Length Min       25           0.126821
# 23    24           Fwd Act Data Pkts       15           0.067480
# 24    25  Total Length of Fwd Packet       29           0.060275
# 25    26                 Fwd IAT Std        0           0.044046
# 26    27                  Active Std        8           0.035912
# 27    28            Total Fwd Packet        1           0.012771
# 28    29                    Idle Std        6           0.012113
# 29    30                 Bwd IAT Min       27           0.008896
# client_2
# /tmp/ipykernel_3100322/2158537172.py:23: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                       original  Cluster  Label_Correlation
# 1             Total Fwd Packet        0           0.012111
# 2            Total Bwd packets        0           0.008571
# 4   Total Length of Bwd Packet        0           0.007856
# 24           Bwd Header Length        0           0.007658
# 23           Fwd Header Length        0           0.009762
# 26           Packet Length Max        1           0.907714
# 8        Bwd Packet Length Max        1           0.937084
# 0                Flow Duration        2           0.175777
# 15               Fwd IAT Total        2           0.175879
# 39                    Idle Max        3           0.294574
# 17                 Fwd IAT Max        3           0.292785
# 13                Flow IAT Max        3           0.292729
# 32            Fwd Seg Size Min        4           0.331336
# 40                    Idle Min        5           0.400868
# 38                    Idle Std        6           0.013190
# 36                  Active Min        7           0.273140
# 31           Fwd Act Data Pkts        8           0.069247
# 28      Packet Length Variance        9           0.826762
# 25           Packet Length Min       10           0.513992
# 37                   Idle Mean       11           0.379683
# 35                  Active Max       12           0.266804
# 10       Bwd Packet Length Std       13           0.905302
# 29          FWD Init Win Bytes       14           0.868180
# 33                 Active Mean       15           0.275122
# 30          Bwd Init Win Bytes       16           0.817880
# 22                 Bwd IAT Min       17           0.553946
# 18                 Fwd IAT Min       18           0.805832
# 16                 Fwd IAT Std       19           0.035728
# 12                Flow IAT Std       20           0.210866
# 21                 Bwd IAT Max       21           0.355228
# 14                Flow IAT Min       22           0.427769
# 34                  Active Std       23           0.035622
# 27           Packet Length Std       24           0.824796
# 5        Fwd Packet Length Max       25           0.579068
# 11               Flow IAT Mean       26           0.519275
# 6        Fwd Packet Length Min       27           0.975815
# 9        Bwd Packet Length Min       28           0.139499
# 7        Fwd Packet Length Std       29           0.699801
# 19               Bwd IAT Total       30           0.346581
# 3   Total Length of Fwd Packet       31           0.062212
# 20                 Bwd IAT Std       32           0.120167
#     Rank                    original  Cluster  Label_Correlation
# 0      1       Fwd Packet Length Min       27           0.975815
# 1      2       Bwd Packet Length Max        1           0.937084
# 2      3       Bwd Packet Length Std       13           0.905302
# 3      4          FWD Init Win Bytes       14           0.868180
# 4      5      Packet Length Variance        9           0.826762
# 5      6           Packet Length Std       24           0.824796
# 6      7          Bwd Init Win Bytes       16           0.817880
# 7      8                 Fwd IAT Min       18           0.805832
# 8      9       Fwd Packet Length Std       29           0.699801
# 9     10       Fwd Packet Length Max       25           0.579068
# 10    11                 Bwd IAT Min       17           0.553946
# 11    12               Flow IAT Mean       26           0.519275
# 12    13           Packet Length Min       10           0.513992
# 13    14                Flow IAT Min       22           0.427769
# 14    15                    Idle Min        5           0.400868
# 15    16                   Idle Mean       11           0.379683
# 16    17                 Bwd IAT Max       21           0.355228
# 17    18               Bwd IAT Total       30           0.346581
# 18    19            Fwd Seg Size Min        4           0.331336
# 19    20                    Idle Max        3           0.294574
# 20    21                 Active Mean       15           0.275122
# 21    22                  Active Min        7           0.273140
# 22    23                  Active Max       12           0.266804
# 23    24                Flow IAT Std       20           0.210866
# 24    25               Fwd IAT Total        2           0.175879
# 25    26       Bwd Packet Length Min       28           0.139499
# 26    27                 Bwd IAT Std       32           0.120167
# 27    28           Fwd Act Data Pkts        8           0.069247
# 28    29  Total Length of Fwd Packet       31           0.062212
# 29    30                 Fwd IAT Std       19           0.035728
# 30    31                  Active Std       23           0.035622
# 31    32                    Idle Std        6           0.013190
# 32    33            Total Fwd Packet        0           0.012111
# client_3
# /tmp/ipykernel_3100322/2158537172.py:23: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                       original  Cluster  Label_Correlation
# 2            Total Bwd packets        0           0.025676
# 24           Bwd Header Length        0           0.020716
# 18                 Fwd IAT Min        1           0.200122
# 14                Flow IAT Min        1           0.203381
# 1             Total Fwd Packet        2           0.026605
# 23           Fwd Header Length        2           0.023555
# 26           Packet Length Max        3           0.922870
# 8        Bwd Packet Length Max        3           0.933615
# 39                    Idle Max        4           0.080346
# 13                Flow IAT Max        4           0.082464
# 37                   Idle Mean        5           0.040215
# 0                Flow Duration        6           0.110945
# 15               Fwd IAT Total        6           0.107826
# 6        Fwd Packet Length Min        7           0.427420
# 25           Packet Length Min        7           0.432511
# 38                    Idle Std        8           0.198788
# 40                    Idle Min        9           0.024042
# 36                  Active Min       10           0.030987
# 34                  Active Std       11           0.063580
# 19               Bwd IAT Total       12           0.132998
# 20                 Bwd IAT Std       13           0.473559
# 35                  Active Max       14           0.066729
# 29          FWD Init Win Bytes       15           0.846433
# 30          Bwd Init Win Bytes       16           0.220190
# 28      Packet Length Variance       17           0.770286
# 16                 Fwd IAT Std       18           0.232182
# 22                 Bwd IAT Min       19           0.049778
# 21                 Bwd IAT Max       20           0.414712
# 9        Bwd Packet Length Min       21           0.208389
# 31           Fwd Act Data Pkts       22           0.016084
# 27           Packet Length Std       23           0.794485
# 32            Fwd Seg Size Min       24           0.282190
# 5        Fwd Packet Length Max       25           0.660555
# 4   Total Length of Bwd Packet       26           0.021827
# 7        Fwd Packet Length Std       27           0.235546
# 11               Flow IAT Mean       28           0.182506
# 33                 Active Mean       29           0.045518
# 12                Flow IAT Std       30           0.183000
# 10       Bwd Packet Length Std       31           0.891384
# 3   Total Length of Fwd Packet       32           0.004837
# 17                 Fwd IAT Max       33           0.077203
#     Rank                    original  Cluster  Label_Correlation
# 0      1       Bwd Packet Length Max        3           0.933615
# 1      2       Bwd Packet Length Std       31           0.891384
# 2      3          FWD Init Win Bytes       15           0.846433
# 3      4           Packet Length Std       23           0.794485
# 4      5      Packet Length Variance       17           0.770286
# 5      6       Fwd Packet Length Max       25           0.660555
# 6      7                 Bwd IAT Std       13           0.473559
# 7      8           Packet Length Min        7           0.432511
# 8      9                 Bwd IAT Max       20           0.414712
# 9     10            Fwd Seg Size Min       24           0.282190
# 10    11       Fwd Packet Length Std       27           0.235546
# 11    12                 Fwd IAT Std       18           0.232182
# 12    13          Bwd Init Win Bytes       16           0.220190
# 13    14       Bwd Packet Length Min       21           0.208389
# 14    15                Flow IAT Min        1           0.203381
# 15    16                    Idle Std        8           0.198788
# 16    17                Flow IAT Std       30           0.183000
# 17    18               Flow IAT Mean       28           0.182506
# 18    19               Bwd IAT Total       12           0.132998
# 19    20               Flow Duration        6           0.110945
# 20    21                Flow IAT Max        4           0.082464
# 21    22                 Fwd IAT Max       33           0.077203
# 22    23                  Active Max       14           0.066729
# 23    24                  Active Std       11           0.063580
# 24    25                 Bwd IAT Min       19           0.049778
# 25    26                 Active Mean       29           0.045518
# 26    27                   Idle Mean        5           0.040215
# 27    28                  Active Min       10           0.030987
# 28    29            Total Fwd Packet        2           0.026605
# 29    30           Total Bwd packets        0           0.025676
# 30    31                    Idle Min        9           0.024042
# 31    32  Total Length of Bwd Packet       26           0.021827
# 32    33           Fwd Act Data Pkts       22           0.016084
# 33    34  Total Length of Fwd Packet       32           0.004837
# client_4
# /tmp/ipykernel_3100322/2158537172.py:23: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = sch.linkage(distance_matrix, method='ward')
# /home/sharedrive/PythonCodes/.venv311_new/lib/python3.11/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                       original  Cluster  Label_Correlation
# 1             Total Fwd Packet        0           0.031266
# 23           Fwd Header Length        0           0.028068
# 8        Bwd Packet Length Max        1           0.932317
# 26           Packet Length Max        1           0.921215
# 30          Bwd Init Win Bytes        2           0.851504
# 29          FWD Init Win Bytes        2           0.851469
# 13                Flow IAT Max        3           0.185221
# 39                    Idle Max        3           0.186967
# 17                 Fwd IAT Max        3           0.189695
# 14                Flow IAT Min        4           0.459391
# 18                 Fwd IAT Min        4           0.456414
# 37                   Idle Mean        5           0.242331
# 33                 Active Mean        6           0.053569
# 38                    Idle Std        7           0.219276
# 15               Fwd IAT Total        8           0.070663
# 0                Flow Duration        8           0.072537
# 6        Fwd Packet Length Min        9           0.989479
# 25           Packet Length Min        9           0.990134
# 40                    Idle Min       10           0.303618
# 34                  Active Std       11           0.101519
# 20                 Bwd IAT Std       12           0.510115
# 22                 Bwd IAT Min       13           0.055314
# 27           Packet Length Std       14           0.910830
# 31           Fwd Act Data Pkts       15           0.013545
# 32            Fwd Seg Size Min       16           0.276888
# 9        Bwd Packet Length Min       17           0.178825
# 16                 Fwd IAT Std       18           0.217826
# 36                  Active Min       19           0.035615
# 28      Packet Length Variance       20           0.810237
# 5        Fwd Packet Length Max       21           0.659167
# 35                  Active Max       22           0.081874
# 19               Bwd IAT Total       23           0.131594
# 24           Bwd Header Length       24           0.034816
# 7        Fwd Packet Length Std       25           0.764144
# 12                Flow IAT Std       26           0.169383
# 4   Total Length of Bwd Packet       27           0.037319
# 10       Bwd Packet Length Std       28           0.890140
# 11               Flow IAT Mean       29           0.438209
# 21                 Bwd IAT Max       30           0.523337
# 3   Total Length of Fwd Packet       31           0.004774
# 2            Total Bwd packets       32           0.040297
#     Rank                    original  Cluster  Label_Correlation
# 0      1           Packet Length Min        9           0.990134
# 1      2       Bwd Packet Length Max        1           0.932317
# 2      3           Packet Length Std       14           0.910830
# 3      4       Bwd Packet Length Std       28           0.890140
# 4      5          Bwd Init Win Bytes        2           0.851504
# 5      6      Packet Length Variance       20           0.810237
# 6      7       Fwd Packet Length Std       25           0.764144
# 7      8       Fwd Packet Length Max       21           0.659167
# 8      9                 Bwd IAT Max       30           0.523337
# 9     10                 Bwd IAT Std       12           0.510115
# 10    11                Flow IAT Min        4           0.459391
# 11    12               Flow IAT Mean       29           0.438209
# 12    13                    Idle Min       10           0.303618
# 13    14            Fwd Seg Size Min       16           0.276888
# 14    15                   Idle Mean        5           0.242331
# 15    16                    Idle Std        7           0.219276
# 16    17                 Fwd IAT Std       18           0.217826
# 17    18                 Fwd IAT Max        3           0.189695
# 18    19       Bwd Packet Length Min       17           0.178825
# 19    20                Flow IAT Std       26           0.169383
# 20    21               Bwd IAT Total       23           0.131594
# 21    22                  Active Std       11           0.101519
# 22    23                  Active Max       22           0.081874
# 23    24               Flow Duration        8           0.072537
# 24    25                 Bwd IAT Min       13           0.055314
# 25    26                 Active Mean        6           0.053569
# 26    27           Total Bwd packets       32           0.040297
# 27    28  Total Length of Bwd Packet       27           0.037319
# 28    29                  Active Min       19           0.035615
# 29    30           Bwd Header Length       24           0.034816
# 30    31            Total Fwd Packet        0           0.031266
# 31    32           Fwd Act Data Pkts       15           0.013545
# 32    33  Total Length of Fwd Packet       31           0.004774
